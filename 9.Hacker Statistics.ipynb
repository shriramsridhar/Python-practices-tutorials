# %% [markdown]
# ## Hackers Statistics

# %%
#To generate a random number in Python
import numpy as np
np.random.rand()    #random is a sub-package in numpy, rand() i generates pseudo random numbers
# Out:
# 0.9213718904216439

# %%
import numpy as np
np.random.seed(123)
np.random.rand()
# Out:
# 0.6964691855978616

# %%
import numpy as np
np.random.seed(123)
print(np.random.rand())    #Above and current random numbers are equal. Random numbers can be generated with consistency like this.
print(np.random.rand())
# Out:
# 0.6964691855978616
# 0.28613933495037946

# %%
#Coin toss simulation using rand()
import numpy as np
np.random.seed(123)
Toss=np.random.randint(0,2)    #Randomly generate 0,1. Range start - 0, end -2(Excluded)
print(Toss)
if Toss==0:
    print("Heads")
else:
    Print("Tails")
# Out:
# 0
# Heads

# %%
#Rolling dice simulation
import numpy as np
np.random.seed(123)

# Use randint() to simulate a dice
print(np.random.randint(1,7))

# Use randint() again
print(np.random.randint(1,7))
# Out:
# 6
# 3

# %%
#Exercise 1:
import numpy as np
np.random.seed(123)

# Starting step
step = 50

# Roll the dice
dice=np.random.randint(1,7)

# Finish the control construct
if dice <= 2 :
    step = step - 1
elif dice >=3 and dice <=5 :
    step+=1
else:
    step = step + np.random.randint(1,7)

# Print out dice and step
print(dice)
print(step)
# Out:
# 6
# 53

# %%
#Coin toss simulation in a list
import numpy as np
np.random.seed(123)
outcome=[]
for i in range(10):
    toss=np.random.randint(0,2)
    if toss==0:
        outcome.append('Heads')
    else:
        outcome.append('Tails')
print(outcome)
# Out:
# ['Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads']

# %%
#Same program but counting the number of tails occurence
import numpy as np
np.random.seed(123)
tails=[0]
for x in range (10):
    coin=np.random.randint(0,2)
    tails.append(tails[x]+coin)
print(tails)
# Out:
# [0, 0, 1, 1, 1, 1, 1, 1, 2, 3, 3]

# %%
import numpy as np

# Initialize random_walk
random_walk=[0]

# Complete the for loop
for x in range(100) :
    # Set step: last element in random_walk
    step=random_walk[-1]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        step = step - 1
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# Print random_walk
print(random_walk)
# Out:
# [0, 1, 0, -1, -2, -3, -4, -5, -6, -7, -6, -1, -2, -3, -2, -3, -2, -1, 0, 1, 2, 1, 2, 1, 2, 3, 4, 5, 4, 8, 9, 8, 9, 8, 9, 10, 11, 12, 13, 14, 15, 18, 19, 20, 21, 26, 27, 31, 32, 31, 32, 33, 32, 33, 34, 36, 37, 38, 37, 36, 37, 38, 37, 36, 37, 38, 40, 39, 38, 39, 38, 39, 40, 41, 43, 42, 43, 44, 45, 46, 47, 46, 45, 46, 45, 46, 47, 46, 49, 50, 51, 52, 51, 52, 53, 57, 56, 55, 57, 56, 57]

# %%
import numpy as np

# Initialize random_walk
random_walk=[0]

# Complete the for loop
for x in range(100) :
    # Set step: last element in random_walk
    step=random_walk[-1]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        step=max(0,step-1)    #max function ensures that step value doesn't go below 0 (0 is passed inside the function) 
        #step = step - 1
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# Print random_walk
print(random_walk)
# Out:
# [0, 1, 0, 1, 2, 3, 2, 3, 2, 3, 4, 6, 5, 4, 5, 6, 5, 7, 8, 9, 10, 11, 12, 13, 12, 13, 14, 19, 20, 19, 18, 17, 16, 17, 18, 19, 24, 25, 24, 25, 26, 27, 28, 29, 30, 29, 28, 29, 28, 34, 33, 34, 33, 34, 33, 34, 38, 42, 44, 46, 45, 46, 48, 47, 53, 54, 56, 57, 56, 57, 58, 59, 58, 59, 60, 61, 63, 62, 61, 62, 68, 73, 72, 71, 75, 76, 77, 78, 80, 79, 80, 79, 80, 79, 78, 84, 83, 84, 85, 86, 87]

# %%
#Visualizing the above code using matplotlib package
import numpy as np

# Initialization
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Plot random_walk
plt.plot(random_walk)


# Show the plot
plt.show()

# %%
#Simulating the occurance of total tails in 10 coin dices.The simulation is done 10000 times to see total tails in 10 dice rolls.
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123)
final_total=[]
for i in range(10000):
    tails=[0]
    for x in range(10):
        coin=np.random.randint(0,2)
        tails.append(tails[x]+coin)
    #last_element=tails[-1]
    final_total.append(tails[-1])
plt.hist(final_total,bins=10)
plt.show()

# %%
#Exercise:
import numpy as np
np.random.seed(123)

# Initialize all_walks (don't change this line)
all_walks = []

# Simulate random walk 10 times
for i in range(10) :

    # Code from before
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)

        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)

    # Append random_walk to all_walks
    all_walks.append(random_walk)

# Print all_walks
print(all_walks)
# Out:
# [[0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 6, 5, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 8, 9, 10, 11, 12, 11, 15, 16, 15, 16, 15, 16, 17, 18, 19, 20, 21, 22, 25, 26, 27, 28, 33, 34, 38, 39, 38, 39, 40, 39, 40, 41, 43, 44, 45, 44, 43, 44, 45, 44, 43, 44, 45, 47, 46, 45, 46, 45, 46, 47, 48, 50, 49, 50, 51, 52, 53, 54, 53, 52, 53, 52, 53, 54, 53, 56, 57, 58, 59, 58, 59, 60], [0, 4, 3, 2, 4, 3, 4, 6, 7, 8, 13, 12, 13, 14, 15, 16, 17, 16, 21, 22, 23, 24, 23, 22, 21, 20, 19, 20, 21, 22, 28, 27, 26, 25, 26, 27, 28, 27, 28, 29, 28, 33, 34, 33, 32, 31, 30, 31, 30, 29, 31, 32, 35, 36, 38, 39, 40, 41, 40, 39, 40, 41, 42, 43, 42, 43, 44, 45, 48, 49, 50, 49, 50, 49, 50, 51, 52, 56, 55, 54, 55, 56, 57, 56, 57, 56, 57, 59, 64, 63, 64, 65, 66, 67, 68, 69, 68, 69, 70, 71, 73], [0, 2, 1, 2, 3, 6, 5, 6, 5, 6, 7, 8, 7, 8, 7, 8, 9, 11, 10, 9, 10, 11, 10, 12, 13, 14, 15, 16, 17, 18, 17, 18, 19, 24, 25, 24, 23, 22, 21, 22, 23, 24, 29, 30, 29, 30, 31, 32, 33, 34, 35, 34, 33, 34, 33, 39, 38, 39, 38, 39, 38,
# ...

# %%
#Exercise:
import numpy as np
np.random.seed(123)

# initialize and populate all_walks
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_aw=np.array(all_walks)
print(np_aw)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t=np.transpose(np_aw)
print(np_aw_t)
# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()
# Out:
# [[ 0  3  4 ... 58 59 60]
#  [ 0  4  3 ... 70 71 73]
#  [ 0  2  1 ... 85 84 83]
#  ...
#  [ 0  0  1 ... 74 75 76]
#  [ 0  1  0 ... 60 61 60]
#  [ 0  1  2 ... 85 86 87]]
# [[ 0  0  0 ...  0  0  0]
#  [ 3  4  2 ...  0  1  1]
#  [ 4  3  1 ...  1  0  2]
#  ...
#  [58 70 85 ... 74 60 85]
#  [59 71 84 ... 75 61 86]
#  [60 73 83 ... 76 60 87]]

# %%
#Exercise:
import numpy as np
np.random.seed(123)

# Simulate random walk 250 times
all_walks = []
for i in range(250) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand() <= 0.001 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()

# %%
#Exercise:
import numpy as np
np.random.seed(123)
# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))

# Select last row from np_aw_t: ends
ends = np_aw_t[-1,]

# Plot histogram of ends, display plot
plt.hist(ends,bins =10)
plt.show()

# %%
ends.count(ends>500)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-1ffc2f564363> in <module>
# ----> 1 ends.count(ends>500)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'
